# %%
import pandas as pd
import datetime as dt

# %%
df = pd.read_csv('job_descriptions.csv')

# %%
df.head()
# Out:
#              Job Id     Experience Qualifications Salary Range    location  \
# 0  1089843540111562  5 to 15 Years         M.Tech    $59K-$99K     Douglas
# 1   398454096642776  2 to 12 Years            BCA   $56K-$116K    Ashgabat
# 2   481640072963533  0 to 12 Years            PhD   $61K-$104K       Macao
# 3   688192671473044  4 to 11 Years            PhD    $65K-$91K  Porto-Novo
# 4   117057806156508  1 to 12 Years            MBA    $64K-$87K    Santiago
#
#             Country  latitude  longitude  Work Type  Company Size  ...  \
# 0       Isle of Man   54.2361    -4.5481     Intern         26801  ...
# 1      Turkmenistan   38.9697    59.5563     Intern        100340  ...
# 2  Macao SAR, China   22.1987   113.5439  Temporary         84525  ...
# 3             Benin    9.3077     2.3158  Full-Time        129896  ...
# 4             Chile  -35.6751   -71.5429     Intern         53944  ...
#
#                  Contact                     Job Title  \
# ...

# %%
# Filter conditions
filtered_df = df[
    (df['Work Type'] == 'Intern') &
    (df['latitude'] < 10) &
    (~df['Country'].str.startswith(('A', 'B', 'C', 'D'))) &
    (df['Company Size'] < 50000)
]

# %%
# Ensure job title does not contain more than 10 words
filtered_df = filtered_df[filtered_df['Job Title'].str.split().str.len() <= 10]

# %%
# Check current time and apply time restrictions
current_time = dt.datetime.now().time()

# %%
if filtered_df.empty:
    print("No data available after applying the filters.")
else:
    print(f"Filtered data contains {len(filtered_df)} records.")
    
    print(filtered_df.head())

    # Check current time and apply time restrictions
    current_time = dt.datetime.now().time()

    if not (dt.time(13, 0) <= current_time <= dt.time(14, 0) or dt.time(18, 0) <= current_time <= dt.time(19, 0)):
        # Plot the chart if within allowed times

        aggregated_data = filtered_df.groupby('Preference').size()

        # Plotting
        plt.figure(figsize=(10, 6))
        aggregated_data.plot(kind='bar')
        plt.xlabel('Preference')
        plt.ylabel('Count')
        plt.title('Preference vs Work Type for Interns')
        plt.show()
    else:
        print("Chart is not displayed due to time restrictions.")
# Out:
# Filtered data contains 25516 records.
#                Job Id     Experience Qualifications Salary Range   location  \
# 101  1156025606824277  4 to 11 Years          M.Com   $55K-$118K    Jakarta
# 123  1846193207686983  5 to 10 Years             BA   $56K-$129K  AsunciÃ³n
# 171  2276733529605345  2 to 10 Years            MCA   $59K-$120K       Suva
# 217   773798251416336   5 to 9 Years         B.Tech    $57K-$82K       Juba
# 223  1225535036606351   1 to 9 Years         B.Tech   $56K-$116K       Dili
#
#          Country   latitude   longitude Work Type  Company Size  ...  \
# 101    Indonesia  -0.789300  113.921300    Intern         39646  ...
# 123     Paraguay -23.442503  -58.443832    Intern         28874  ...
# 171         Fiji -17.713400  178.065000    Intern         33129  ...
# 217  South Sudan   6.877000   31.307000    Intern         26133  ...
# 223  Timor-Leste  -8.874200  125.727500    Intern         47263  ...
#
#                     Contact              Job Title  \
# ...

# %% [markdown]
# By Pritesh Lungare
